# %%
import pandas as pd
import datetime as dt
import numpy as np

# %%
trips = pd.read_csv('https://raw.githubusercontent.com/clausmsaau/Dataanalyse2022/main/trips.csv')
people = pd.read_csv('https://raw.githubusercontent.com/clausmsaau/Dataanalyse2022/main/people.csv')
countrylist = pd.read_csv('https://raw.githubusercontent.com/clausmsaau/Dataanalyse2022/main/countrylist.csv')

# %%
trips.head()
# Out:
#    Unnamed: 0          username country country_code country_slug    date_end  \
# 0           0  @lewellenmichael  Mexico           MX       mexico  2018-06-15
# 1           1  @lewellenmichael  Mexico           MX       mexico  2018-06-03
# 2           2  @lewellenmichael  Mexico           MX       mexico  2017-11-05
# 3           3  @lewellenmichael  Jordan           JO       jordan  2017-08-07
# 4           4      @waylandchin   China           CN        china  2017-03-18
#
#    date_start  latitude  longitude        place          place_slug
# 0  2018-06-04        21       -101   Guanajuato              mexico
# 1  2018-05-31        19        -99  Mexico City  mexico-city-mexico
# 2  2017-11-01        21        -86       Cancun       cancun-mexico
# 3  2017-07-24        31         35        Amman        amman-jordan
# 4  2017-02-17        40        122      Yingkou               china

# %%
people.head()
# Out:
#    Unnamed: 0          username  followers  following  \
# 0           0  @lewellenmichael          1          2
# 1           1      @waylandchin          0          2
# 2           2            @karan          2          1
# 3           3       @skaboss217          0          1
# 4           4             @apwn         17        426
#
#                                             work_raw  \
# 0  Software Dev, Startup Founder, Finance, Crypto...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                            Web Dev
#
#                     education_raw
# 0  High School, Bachelor's Degree
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
countrylist.head()
# Out:
#   alpha_2   region       sub_region
# 0      AF     Asia    Southern Asia
# 1      AX   Europe  Northern Europe
# 2      AL   Europe  Southern Europe
# 3      DZ   Africa  Northern Africa
# 4      AS  Oceania        Polynesia

# %%
trips
# Out:
#        Unnamed: 0          username        country country_code  \
# 0               0  @lewellenmichael         Mexico           MX
# 1               1  @lewellenmichael         Mexico           MX
# 2               2  @lewellenmichael         Mexico           MX
# 3               3  @lewellenmichael         Jordan           JO
# 4               4      @waylandchin          China           CN
# ...           ...               ...            ...          ...
# 46505       46505         @antonioc           Cuba           CU
# 46506       46506         @antonioc     Costa Rica           CR
# 46507       46507         @antonioc  United States           US
# 46508       46508         @jrearden  United States           US
# 46509       46509       @kschroeder      Argentina           AR
#
#         country_slug    date_end  date_start  latitude  longitude  \
# 0             mexico  2018-06-15  2018-06-04        21       -101
# ...
